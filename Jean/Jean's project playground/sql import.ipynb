# %%
import pyodbc

server = 'john-server'
database = 'sum_2023'
username = 'jeanbatista48'
password = 'CCny23916948'
driver= '{ODBC Driver 17 for SQL Server}'

cnxn = pyodbc.connect('DRIVER='+driver+';PORT=1433;SERVER='+server+';PORT=1443;DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
cursor.execute("SELECT * FROM pizza_types;")

row = cursor.fetchone()
for x in row:
    print(x)

cursor.close()
print(    )

sql_query = pd.read_sql("SELECT * FROM pizza_types;" ,cnxn)
df = pd.DataFrame(sql_query, columns = ['pizza_type_id', 'name', 'category','ingredients'])
print(df)
# Out:
# bbq_ckn
# The Barbecue Chicken Pizza
# Chicken
# Barbecued Chicken, Red Peppers, Green Peppers, Tomatoes, Red Onions, Barbecue Sauce
#
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       big_meat                          The Big Meat Pizza  Classic
# 2     brie_carre                        The Brie Carre Pizza  Supreme
# 3      calabrese                         The Calabrese Pizza  Supreme
# 4       cali_ckn                The California Chicken Pizza  Chicken
# 5    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 6      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8    five_cheese                       The Five Cheese Pizza   Veggie
# 9    four_cheese                       The Four Cheese Pizza   Veggie
# ...
